# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("../data/cleaned_data.csv")
data = df[df["Country"] == "India"]
data = data.groupby("Year")["GDP_USD"].mean().reset_index()
data = data.sort_values("Year")
plt.figure()
plt.plot(data["Year"], data["GDP_USD"]/1e12, marker="o")
plt.title("GDP Trend - India")
plt.xlabel("Year")
plt.ylabel("GDP (Trillion USD)")
plt.grid(True)
plt.show()

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("../data/cleaned_data.csv")

st.title("Global Economic Intelligence Dashboard")

# Country selector
country = st.selectbox("Select Country", df["Country"].unique())

# Filter data
data = df[df["Country"] == country]
data = data.groupby("Year")["GDP_USD"].mean().reset_index()
data = data.sort_values("Year")

# Plot chart
fig, ax = plt.subplots()

ax.plot(data["Year"], data["GDP_USD"]/1e12, marker="o")

ax.set_title("GDP Trend - " + country)
ax.set_xlabel("Year")
ax.set_ylabel("GDP (Trillion USD)")

st.pyplot(fig)
# Out:
# 2026-03-09 23:41:53.634 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:54.925
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/codie/.cache/yay/anaconda/pkg/anaconda/opt/anaconda/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-03-09 23:41:55.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:55.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:55.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:55.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:56.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:56.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:56.448 Session state does not function when running a script without `streamlit run`
# 2026-03-09 23:41:56.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:56.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:56.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:58.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:59.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:59.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-09 23:41:59.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
